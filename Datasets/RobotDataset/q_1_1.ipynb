# %%
import numpy as num
import pandas as pd
import pprint

# %%
data= pd.read_csv('Robot1', sep=" ", header=None)
data=data.drop(columns=0)
data.columns = ["class","a1","a2","a3","a4","a5","a6","Id"]
# print data
# train_data=data.sample(frac=0.8,random_state=100)
# validation_data=data.drop(train_data.index)
# train_data ,test_data = train_test_set(data ,0.2)
train_data=data.sample(frac=0.8,random_state=200)
validation_data=data.drop(train_data.index)
# print train_data
# print validation_data
# print train_data.iloc[39]['class']
# print train_data.index
list_attributes=["a1","a2","a3","a4","a5","a6"]

# %%
def check_value(validation_data ,list_attributes,train_data,k_value):
    dict_value={}
    list_value=[]
    list_index=[]
    for j in validation_data.index:
        for i in train_data.index:
            sum_value=0
            for attr in list_attributes:
                try:
#                     print train_data.iloc[i][attr]
                    sum_value=sum_value+validation_data.iloc[j][attr]-train_data.iloc[i][attr]
                except:
                    print('hi')
#                     print i ,attr
        list_value.append(sum_value)
        list_index.append(i)
    print (list_value)
    print (list_index)

# %%
# print train_data.iloc[117]
check_value(validation_data,list_attributes,train_data,10)
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# ...
